# %%
import json
import os

# %% [markdown]
# ## Load the data

# %%
with open("../../../data.json") as f:
    wines = json.load(f)

print(f"Found {len(wines)} wines.")
# Out:
# Found 78900 wines.

# %%
print("Save Raw data...")
with open("../../../data_raw.json", "w") as f:
    json.dump(wines, f)
print("Raw data saved!")
# Out:
# Save Raw data...
# Raw data saved!

# %% [markdown]
# ## Remove useless infos
#
# * Removed `prices` column because it is the same as `price`.
# * Removed `seo_name` as we won't use it.
# * Removed `background_image` as we won't use it.
# * Removed `status` as we won't use it.
# * Removed `image` as we won't use it.
# * Removed `grapes` as it is consistently empty.
# * Removed `has_valid_ratings` as we can deduce it from `statistics`.
# * Removed `style` as we won't use it.
# * Removed `vintage_type` as I suspect it to be a duplicate of `vintage`.

# %%
wines[0]
# Out:
# {'vintage': {'id': 8519046,
#   'seo_name': 'franco-biondi-santi-brunello-di-montalcino-riserva-1955',
#   'name': 'Biondi-Santi Brunello di Montalcino Riserva 1955',
#   'statistics': {'status': 'Normal',
#    'ratings_count': 35,
#    'ratings_average': 4.9,
#    'labels_count': 129,
#    'wine_ratings_count': 3375,
#    'wine_ratings_average': 4.6,
#    'wine_status': 'Normal'},
#   'image': {'location': '//images.vivino.com/thumbs/C62n7YRySmOweMGqGhHUwA_pl_480x640.png',
#    'variations': {'bottle_large': '//images.vivino.com/thumbs/C62n7YRySmOweMGqGhHUwA_pb_x960.png',
#     'bottle_medium': '//images.vivino.com/thumbs/C62n7YRySmOweMGqGhHUwA_pb_x600.png',
#     'bottle_medium_square': '//images.vivino.com/thumbs/C62n7YRySmOweMGqGhHUwA_pb_600x600.png',
#     'bottle_small': '//images.vivino.com/thumbs/C62n7YRySmOweMGqGhHUwA_pb_x300.png',
#     'bottle_small_square': '//images.vivino.com/thumbs/C62n7YRySmOweMGqGhHUwA_pb_300x300.png',
#     'label': '//images.vivino.com/thumbs/C62n7YRySmOweMGqGhHUwA_pl_480x640.png',
#     'label_large': '//images.vivino.com/thumbs/C62n7YRySmOweMGqGhHUwA_pl_375x500.png',
#     'label_medium': '//images.vivino.com/thumbs/C62n7YRySmOweMGqGhHUwA_pl_150x200.png',
#     'label_medium_square': '//images.vivino.com/thumbs/C62n7YRySmOweMGqGhHUwA_pl_150x150.png',
#     'label_small_square': '//images.vivino.com/thumbs/C62n7YRySmOweMGqGhHUwA_pl_80x80.png',
#     'large': '//images.vivino.com/thumbs/C62n7YRySmOweMGqGhHUwA_pl_375x500.png',
#     'medium': '//images.vivino.com/thumbs/C62n7YRySmOweMGqGhHUwA_pl_150x200.png',
#     'medium_square': '//images.vivino.com/thumbs/C62n7YRySmOweMGqGhHUwA_pl_150x150.png',
#     'small_square': '//images.vivino.com/thumbs/C62n7YRySmOweMGqGhHUwA_pl_80x80.png'}},
#   'wine': {'id': 82698,
#    'name': 'Brunello di Montalcino Riserva',
#    'seo_name': 'brunello-di-montalcino-riserva',
#    'type_id': 1,
#    'vintage_type': 0,
#    'is_natural': False,
#    'region': {'id': 1796,
#     'name': 'Brunello di Montalcino',
#     'name_en': '',
#     'seo_name': 'brunello-di-montalcino',
#     'country': {'code': 'it',
#      'name': 'Italie',
#      'native_name': 'Italia',
#      'seo_name': 'italy',
#      'currency': {'code': 'EUR',
#       'name': 'Euros',
#       'prefix': '€',
#       'suffix': None},
#      'regions_count': 563,
#      'users_count': 4270717,
#      'wines_count': 274658,
#      'wineries_count': 42399,
#      'most_used_grapes': [{'id': 16,
#        'name': 'Sangiovese',
#        'seo_name': 'sangiovese',
#        'has_detailed_info': True,
#        'wines_count': 125094},
#       {'id': 5,
#        'name': 'Chardonnay',
#        'seo_name': 'chardonnay',
#        'has_detailed_info': True,
#        'wines_count': 604208},
#       {'id': 10,
#        'name': 'Merlot',
#        'seo_name': 'merlot',
#        'has_detailed_info': True,
#        'wines_count': 566719}]},
#     'class': {'typecast_map': {'background_image': {}, 'class': {}}},
#     'background_image': {'location': '//images.vivino.com/regions/backgrounds/c25PzK2tRryTKLWVHhqCBA.jpg',
#      'variations': {'large': '//thumbs.vivino.com/region_backgrounds/c25PzK2tRryTKLWVHhqCBA_1280x760.jpg',
#       'medium': '//thumbs.vivino.com/region_backgrounds/c25PzK2tRryTKLWVHhqCBA_600x356.jpg'}}},
#    'winery': {'id': 11500,
#     'name': 'Biondi-Santi',
#     'seo_name': 'franco-biondi-santi',
#     'status': 0,
#     'background_image': None},
#    'taste': {'structure': {'acidity': 3.830859,
#      'fizziness': None,
#      'intensity': 3.1464493,
#      'sweetness': 1.650779,
#      'tannin': 3.602499,
#      'user_structure_count': 173,
#      'calculated_structure_count': 188},
#     'flavor': [{'group': 'earth',
#       'stats': {'count': 159, 'score': 24790},
#       'primary_keywords': [{'id': 242, 'name': 'leather', 'count': 73},
#        {'id': 284, 'name': 'mushroom', 'count': 46},
#        {'id': 156, 'name': 'earthy', 'count': 28},
#        {'id': 22, 'name': 'balsamic', 'count': 23},
#        {'id': 384, 'name': 'smoke', 'count': 21},
#        {'id': 430, 'name': 'truffle', 'count': 16},
#        {'id': 165, 'name': 'forest floor', 'count': 12},
#        {'id': 412, 'name': 'tar', 'count': 10},
#        {'id': 276, 'name': 'minerals', 'count': 9},
#        {'id': 178, 'name': 'game', 'count': 7},
#        {'id': 192, 'name': 'graphite', 'count': 5},
#        {'id': 113, 'name': 'cocoa', 'count': 3},
#        {'id': 14, 'name': 'ash', 'count': 3},
#        {'id': 160, 'name': 'exotic spice', 'count': 2},
#        {'id': 376, 'name': 'saline', 'count': 2},
#        {'id': 398, 'name': 'stone', 'count': 2},
#        {'id': 218, 'name': 'honey', 'count': 2},
#        {'id': 431, 'name': 'underbrush', 'count': 2},
#        {'id': 226, 'name': 'iron', 'count': 1},
#        {'id': 85, 'name': 'chalk', 'count': 1},
#        {'id': 47, 'name': 'black truffle', 'count': 1},
#        {'id': 111, 'name': 'clay pot', 'count': 1},
#        {'id': 377, 'name': 'salt', 'count': 1},
#        {'id': 443, 'name': 'wet gravel', 'count': 1},
#        {'id': 465, 'name': 'rubber', 'count': 1}],
#       'secondary_keywords': [{'id': 422, 'name': 'tobacco', 'count': 57},
#        {'id': 381, 'name': 'savory', 'count': 8},
#        {'id': 134, 'name': 'dark chocolate', 'count': 5},
#        {'id': 280, 'name': 'mocha', 'count': 1},
#        {'id': 6, 'name': 'almond', 'count': 1},
#        {'id': 267, 'name': 'marzipan', 'count': 1}]},
#      {'group': 'oak',
#       'stats': {'count': 140, 'score': 16495},
#       'primary_keywords': [{'id': 422, 'name': 'tobacco', 'count': 57},
#        {'id': 292, 'name': 'oak', 'count': 31},
#        {'id': 117, 'name': 'coffee', 'count': 15},
#        {'id': 101, 'name': 'chocolate', 'count': 13},
#        {'id': 83, 'name': 'cedar', 'count': 13},
#        {'id': 434, 'name': 'vanilla', 'count': 11},
#        {'id': 104, 'name': 'cigar box', 'count': 8},
#        {'id': 112, 'name': 'clove', 'count': 8},
#        {'id': 290, 'name': 'nutmeg', 'count': 6},
#        {'id': 134, 'name': 'dark chocolate', 'count': 5},
#        {'id': 79, 'name': 'caramel', 'count': 4},
#        {'id': 103, 'name': 'cigar', 'count': 3},
#        {'id': 223, 'name': 'incense', 'count': 2},
#        {'id': 424, 'name': 'toffee', 'count': 2},
#        {'id': 118, 'name': 'cola', 'count': 2},
#        {'id': 158, 'name': 'espresso', 'count': 1},
#        {'id': 407, 'name': 'sweet tobacco', 'count': 1},
#        {'id': 280, 'name': 'mocha', 'count': 1}],
#       'secondary_keywords': [{'id': 242, 'name': 'leather', 'count': 73},
#        {'id': 384, 'name': 'smoke', 'count': 21},
#        {'id': 105, 'name': 'cinnamon', 'count': 7},
#        {'id': 14, 'name': 'ash', 'count': 3},
#        {'id': 113, 'name': 'cocoa', 'count': 3},
#        {'id': 6, 'name': 'almond', 'count': 1},
#        {'id': 267, 'name': 'marzipan', 'count': 1},
#        {'id': 213, 'name': 'hazelnut', 'count': 1},
#        {'id': 65, 'name': 'brown sugar', 'count': 1},
#        {'id': 62, 'name': 'brioche', 'count': 1}]},
#      {'group': 'red_fruit',
#       'stats': {'count': 115, 'score': 15156},
#       'primary_keywords': [{'id': 93, 'name': 'cherry', 'count': 58},
#        {'id': 354, 'name': 'red fruit', 'count': 27},
#        {'id': 400, 'name': 'strawberry', 'count': 17},
#        {'id': 348, 'name': 'raspberry', 'count': 15},
#        {'id': 352, 'name': 'red cherry', 'count': 8},
#        {'id': 387, 'name': 'sour cherry', 'count': 7},
#        {'id': 122, 'name': 'cranberry', 'count': 6},
#        {'id': 357, 'name': 'red plum', 'count': 3},
#        {'id': 336, 'name': 'pomegranate', 'count': 3},
#        {'id': 154, 'name': 'dried strawberry', 'count': 2},
#        {'id': 452, 'name': 'wild strawberry', 'count': 1},
#        {'id': 361, 'name': 'ripe strawberry', 'count': 1},
#        {'id': 263, 'name': 'maraschino cherry', 'count': 1},
#        {'id': 353, 'name': 'red currant', 'count': 1}],
#       'secondary_keywords': [{'id': 229, 'name': 'jam', 'count': 9},
#        {'id': 38, 'name': 'black cherry', 'count': 6}]},
#      {'group': 'non_oak',
#       'stats': {'count': 105, 'score': 2961},
#       'primary_keywords': [{'id': 417, 'name': 'toast', 'count': 2},
#        {'id': 291, 'name': 'nutty', 'count': 1},
#        {'id': 6, 'name': 'almond', 'count': 1},
#        {'id': 281, 'name': 'molasses', 'count': 1},
#        {'id': 267, 'name': 'marzipan', 'count': 1},
#        {'id': 262, 'name': 'maple syrup', 'count': 1},
#        {'id': 363, 'name': 'roasted hazelnut', 'count': 1},
#        {'id': 213, 'name': 'hazelnut', 'count': 1},
#        {'id': 65, 'name': 'brown sugar', 'count': 1},
#        {'id': 62, 'name': 'brioche', 'count': 1},
#        {'id': 438, 'name': 'walnut', 'count': 1}],
#       'secondary_keywords': [{'id': 422, 'name': 'tobacco', 'count': 57},
#        {'id': 384, 'name': 'smoke', 'count': 21},
#        {'id': 117, 'name': 'coffee', 'count': 15},
#        {'id': 83, 'name': 'cedar', 'count': 13},
#        {'id': 434, 'name': 'vanilla', 'count': 11},
#        {'id': 112, 'name': 'clove', 'count': 8},
#        {'id': 105, 'name': 'cinnamon', 'count': 7},
#        {'id': 290, 'name': 'nutmeg', 'count': 6},
#        {'id': 79, 'name': 'caramel', 'count': 4},
#        {'id': 163, 'name': 'fig', 'count': 3},
#        {'id': 223, 'name': 'incense', 'count': 2},
#        {'id': 118, 'name': 'cola', 'count': 2},
#        {'id': 407, 'name': 'sweet tobacco', 'count': 1},
#        {'id': 158, 'name': 'espresso', 'count': 1},
#        {'id': 280, 'name': 'mocha', 'count': 1}]},
#      {'group': 'spices',
#       'stats': {'count': 66, 'score': 7863},
#       'primary_keywords': [{'id': 249, 'name': 'licorice', 'count': 23},
#        {'id': 320, 'name': 'pepper', 'count': 10},
#        {'id': 277, 'name': 'mint', 'count': 9},
#        {'id': 381, 'name': 'savory', 'count': 8},
#        {'id': 416, 'name': 'thyme', 'count': 7},
#        {'id': 105, 'name': 'cinnamon', 'count': 7},
#        {'id': 148, 'name': 'dried herbs', 'count': 4},
#        {'id': 273, 'name': 'menthol', 'count': 4},
#        {'id': 159, 'name': 'eucalyptus', 'count': 3},
#        {'id': 375, 'name': 'sage', 'count': 3},
#        {'id': 449, 'name': 'white pepper', 'count': 2},
#        {'id': 303, 'name': 'oregano', 'count': 2},
#        {'id': 153, 'name': 'dried rosemary', 'count': 1},
#        {'id': 373, 'name': 'rosemary', 'count': 1},
#        {'id': 7, 'name': 'anise', 'count': 1}],
#       'secondary_keywords': [{'id': 434, 'name': 'vanilla', 'count': 11},
#        {'id': 112, 'name': 'clove', 'count': 8},
#        {'id': 290, 'name': 'nutmeg', 'count': 6}]},
#      {'group': 'black_fruit',
#       'stats': {'count': 62, 'score': 6722},
#       'primary_keywords': [{'id': 334, 'name': 'plum', 'count': 23},
#        {'id': 52, 'name': 'blackcurrant', 'count': 10},
#        {'id': 229, 'name': 'jam', 'count': 9},
#        {'id': 49, 'name': 'blackberry', 'count': 7},
#        {'id': 135, 'name': 'dark fruit', 'count': 6},
#        {'id': 38, 'name': 'black cherry', 'count': 6},
#        {'id': 39, 'name': 'black fruit', 'count': 3},
#        {'id': 55, 'name': 'blueberry', 'count': 3},
#        {'id': 31, 'name': 'berry jam', 'count': 1},
#        {'id': 470, 'name': 'cassis', 'count': 1},
#        {'id': 41, 'name': 'black olive', 'count': 1}],
#       'secondary_keywords': [{'id': 341, 'name': 'prune', 'count': 8}]},
#      {'group': 'microbio',
#       'stats': {'count': 54, 'score': 3208},
#       'primary_keywords': [{'id': 123, 'name': 'cream', 'count': 3},
#        {'id': 295, 'name': 'oil', 'count': 1}],
#       'secondary_keywords': [{'id': 284, 'name': 'mushroom', 'count': 46},
#        {'id': 430, 'name': 'truffle', 'count': 16},
#        {'id': 424, 'name': 'toffee', 'count': 2},
#        {'id': 417, 'name': 'toast', 'count': 2},
#        {'id': 6, 'name': 'almond', 'count': 1}]},
#      {'group': 'citrus_fruit',
#       'stats': {'count': 29, 'score': 2900},
#       'primary_keywords': [{'id': 298, 'name': 'orange', 'count': 16},
#        {'id': 300, 'name': 'orange peel', 'count': 5},
#        {'id': 302, 'name': 'orange zest', 'count': 3},
#        {'id': 301, 'name': 'orange rind', 'count': 2},
#        {'id': 243, 'name': 'lemon', 'count': 2},
#        {'id': 54, 'name': 'blood orange', 'count': 1}]},
#      {'group': 'floral',
#       'stats': {'count': 26, 'score': 3000},
#       'primary_keywords': [{'id': 152, 'name': 'dried rose', 'count': 10},
#        {'id': 436, 'name': 'violet', 'count': 5},
#        {'id': 371, 'name': 'rose petal', 'count': 5},
#        {'id': 338, 'name': 'potpourri', 'count': 3},
#        {'id': 322, 'name': 'perfume', 'count': 1},
#        {'id': 225, 'name': 'iris', 'count': 1},
#        {'id': 146, 'name': 'dried flowers', 'count': 1},
#        {'id': 157, 'name': 'elderflower', 'count': 1},
#        {'id': 241, 'name': 'lavender', 'count': 1}],
#       'secondary_keywords': [{'id': 381, 'name': 'savory', 'count': 8}]},
#      {'group': 'dried_fruit',
#       'stats': {'count': 24, 'score': 1695},
#       'primary_keywords': [{'id': 341, 'name': 'prune', 'count': 8},
#        {'id': 163, 'name': 'fig', 'count': 3},
#        {'id': 347, 'name': 'raisin', 'count': 3},
#        {'id': 147, 'name': 'dried fruit', 'count': 1},
#        {'id': 144, 'name': 'dried cranberry', 'count': 1}],
#       'secondary_keywords': [{'id': 229, 'name': 'jam', 'count': 9},
#        {'id': 154, 'name': 'dried strawberry', 'count': 2}]},
#      {'group': 'vegetal',
#       'stats': {'count': 18, 'score': 1210},
#       'primary_keywords': [{'id': 212, 'name': 'hay', 'count': 4},
#        {'id': 425, 'name': 'tomato', 'count': 4},
#        {'id': 185, 'name': 'gooseberry', 'count': 1},
#        {'id': 426, 'name': 'tomato leaf', 'count': 1}],
#       'secondary_keywords': [{'id': 381, 'name': 'savory', 'count': 8},
#        {'id': 6, 'name': 'almond', 'count': 1}]},
#      {'group': 'tree_fruit',
#       'stats': {'count': 2, 'score': 200},
#       'primary_keywords': [{'id': 310, 'name': 'peach', 'count': 1},
#        {'id': 19, 'name': 'baked apple', 'count': 1}]}]},
#    'statistics': {'status': 'Normal',
#     'ratings_count': 3375,
#     'ratings_average': 4.6,
#     'labels_count': 18410,
#     'vintages_count': 136},
#    'style': {'id': 22,
#     'seo_name': 'italian-brunello',
#     'regional_name': 'Italien',
#     'varietal_name': 'Brunello',
#     'name': 'Brunello (Italie)',
#     'image': None,
#     'background_image': None,
#     'description': "From Tuscany in central Italy, Brunello enjoys a distinction as one of Italy's most favored wines.\n\nBrunello ages well and is great for collecting. The wine is bold, rich, and full-bodied. Red and black fruit assertively grace the nose and palate.\n\nBrunello is made totally from Sangiovese grapes that take on the characteristics of the soil, vegetation and climate of the region in which it is grown.\n\nLayered aromas and velvety tannins complement medium-high acidity. Consider decanting this wine to enjoy its full complexity.\n\nThis wine pairs well with big protein ladened dishes. You may also enjoy it with salted cheeses and cured meats. Try to avoid pairing with dishes where the wine would overwhelm flavors, such as leafy greens and subtly seasoned meats.",
#     'blurb': 'Vin DOCG sangiovese de Toscane',
#     'interesting_facts': ['There are fewer than 10 winemakers for all Brunello in all of Italy. There are, however, scores of vineyards in a very small area.',
#      'Italian wine law prohibits any temperature intervention in the growing cycle of Brunello grapes.',
#      'Brunello comes from a particular Sangiovese grape - the same grape from which Chianti is made.'],
#     'body': 5,
#     'body_description': 'Très corsé',
#     'acidity': 3,
#     'acidity_description': 'Élevée',
#     'country': {'code': 'it',
#      'name': 'Italie',
#      'native_name': 'Italia',
#      'seo_name': 'italy',
#      'currency': {'code': 'EUR',
#       'name': 'Euros',
#       'prefix': '€',
#       'suffix': None},
#      'regions_count': 563,
#      'users_count': 4270717,
#      'wines_count': 274658,
#      'wineries_count': 42399,
#      'most_used_grapes': [{'id': 16,
#        'name': 'Sangiovese',
#        'seo_name': 'sangiovese',
#        'has_detailed_info': True,
#        'wines_count': 125094},
#       {'id': 5,
#        'name': 'Chardonnay',
#        'seo_name': 'chardonnay',
#        'has_detailed_info': True,
#        'wines_count': 604208},
#       {'id': 10,
#        'name': 'Merlot',
#        'seo_name': 'merlot',
#        'has_detailed_info': True,
#        'wines_count': 566719}]},
#     'wine_type_id': 1,
#     'food': [{'id': 4,
#       'name': 'Bœuf',
#       'background_image': {'location': '//images.vivino.com/backgrounds/foods/4_beef.png',
#        'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/4_beef_932x810.png'}},
#       'seo_name': 'beef'},
#      {'id': 8,
#       'name': 'Agneau',
#       'background_image': {'location': '//images.vivino.com/backgrounds/foods/8_lamb.png',
#        'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/8_lamb_932x810.png'}},
#       'seo_name': 'lamb'},
#      {'id': 11,
#       'name': 'Gibier (cerf, chevreuil)',
#       'background_image': {'location': '//images.vivino.com/backgrounds/foods/11_venison.png',
#        'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/11_venison_932x810.png'}},
#       'seo_name': 'game'},
#      {'id': 20,
#       'name': 'Volaille',
#       'background_image': {'location': '//images.vivino.com/backgrounds/foods/20_chicken.png',
#        'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/20_chicken_932x810.png'}},
#       'seo_name': 'poultry'}],
#     'grapes': [{'id': 16,
#       'name': 'Sangiovese',
#       'seo_name': 'sangiovese',
#       'has_detailed_info': True,
#       'wines_count': 125094}],
#     'region': {'id': 394,
#      'name': 'Toscane',
#      'name_en': 'Tuscany',
#      'seo_name': 'tuscany',
#      'country': {'code': 'it',
#       'name': 'Italie',
#       'native_name': 'Italia',
#       'seo_name': 'italy',
#       'currency': {'code': 'EUR',
#        'name': 'Euros',
#        'prefix': '€',
#        'suffix': None},
#       'regions_count': 563,
#       'users_count': 4270717,
#       'wines_count': 274658,
#       'wineries_count': 42399,
#       'most_used_grapes': [{'id': 16,
#         'name': 'Sangiovese',
#         'seo_name': 'sangiovese',
#         'has_detailed_info': True,
#         'wines_count': 125094},
#        {'id': 5,
#         'name': 'Chardonnay',
#         'seo_name': 'chardonnay',
#         'has_detailed_info': True,
#         'wines_count': 604208},
#        {'id': 10,
#         'name': 'Merlot',
#         'seo_name': 'merlot',
#         'has_detailed_info': True,
#         'wines_count': 566719}]},
#      'parent_id': 4961,
#      'background_image': {'location': '//images.vivino.com/regions/backgrounds/qa-Yh0SLQaGSpaxWw7WHXQ.jpeg',
#       'variations': {'large': '//thumbs.vivino.com/region_backgrounds/qa-Yh0SLQaGSpaxWw7WHXQ_1280x760.jpeg',
#        'medium': '//thumbs.vivino.com/region_backgrounds/qa-Yh0SLQaGSpaxWw7WHXQ_600x356.jpeg'}},
#      'class': {'typecast_map': {'background_image': {}, 'class': {}}},
#      'statistics': {'wineries_count': 6624,
#       'wines_count': 31426,
#       'sub_regions_count': 44,
#       'parent_regions_count': 1}},
#     'parent_style_id': 292,
#     'hidden': False,
#     'statistics': {'wines_count': 1596, 'aggregated_wines_count': 1596},
#     'vintage_mask': '4<',
#     'baseline_structure': {'acidity': 4.0,
#      'fizziness': None,
#      'intensity': 3.0,
#      'sweetness': 1.0,
#      'tannin': 4.0}},
#    'has_valid_ratings': True},
#   'year': 1955,
#   'grapes': None,
#   'has_valid_ratings': True},
#  'price': {'id': 21578167,
#   'amount': 1970.05,
#   'discounted_from': None,
#   'discount_percent': None,
#   'type': 'vc',
#   'sku': 'a4e52cdf-35b5-4630-96fa-fc358937c565',
#   'url': 'https://hermanwines.com/products/brunello-riserva-biondi-santi-1955-r-0-75l',
#   'visibility': 1,
#   'bottle_type_id': 1,
#   'currency': {'code': 'EUR', 'name': 'Euros', 'prefix': '€', 'suffix': None},
#   'bottle_type': {'id': 1,
#    'name': 'Bouteille (75cl)',
#    'short_name': 'bouteille',
#    'short_name_plural': 'bouteilles',
#    'volume_ml': 750}},
#  'prices': [{'id': 21578167,
#    'amount': 1970.05,
#    'discounted_from': None,
#    'discount_percent': None,
#    'type': 'vc',
#    'sku': 'a4e52cdf-35b5-4630-96fa-fc358937c565',
#    'url': 'https://hermanwines.com/products/brunello-riserva-biondi-santi-1955-r-0-75l',
#    'visibility': 1,
#    'bottle_type_id': 1,
#    'currency': {'code': 'EUR', 'name': 'Euros', 'prefix': '€', 'suffix': None},
#    'bottle_type': {'id': 1,
#     'name': 'Bouteille (75cl)',
#     'short_name': 'bouteille',
#     'short_name_plural': 'bouteilles',
#     'volume_ml': 750}}]}

# %%
for i, wine in enumerate(wines):
    wine.pop('prices', True)
    # vintage
    wine['vintage'].pop('seo_name')
    wine['vintage'].pop('image')
    wine['vintage'].pop('grapes')
    wine['vintage'].pop('has_valid_ratings')
    # Wine
    wine['vintage']['wine'].pop('seo_name')
    wine['vintage']['wine'].pop('type_id')
    wine['vintage']['wine'].pop('has_valid_ratings')
    wine['vintage']['wine'].pop('style')
    wine['vintage']['wine'].pop('vintage_type')
    # Region
    wine['vintage']['wine']['region'].pop('seo_name')
    wine['vintage']['wine']['region'].pop('name_en')
    # Can not have a class
    wine['vintage']['wine']['region'].pop('class', True)
    wine['vintage']['wine']['region'].pop('background_image')
    # country 
    wine['vintage']['wine']['region']['country'].pop('native_name')
    wine['vintage']['wine']['region']['country'].pop('seo_name')
    wine['vintage']['wine']['region']['country'].pop('currency')
    for grape in wine['vintage']['wine']['region']['country']['most_used_grapes']:
        grape.pop('seo_name')
        grape.pop('has_detailed_info')
    # Winery
    wine['vintage']['wine']['winery'].pop('seo_name')
    wine['vintage']['wine']['winery'].pop('background_image')
    wine['vintage']['wine']['winery'].pop('status')
    # Price
    wine['vintage']['wine']['url'] = wine['price']['url']
    wine['price']['bottle_volume_ml'] = wine['price']['bottle_type']['volume_ml']
    wine['price'].pop('bottle_type')
    wine['price']['amount_in_euros'] = wine['price']['amount']
    wine['price'].pop('amount')
    wine['price'].pop('currency')
    wine['price'].pop('id')
    wine['price'].pop('type')
    wine['price'].pop('sku')
    wine['price'].pop('url')
    wine['price'].pop('visibility')
    wine['price'].pop('bottle_type_id')
    
    if wine['vintage'].get('top_list_rankings'):
        # Top list ranking
        for rank in wine['vintage']['top_list_rankings']:
            rank.pop('description')
            rank['top_list'].pop('seo_name')
            rank['top_list'].pop('type')
            # Most of the time empty
            rank['top_list'].pop('year')

# %%
print("all done! Saving results...")
with open("../../../data_cleaned.json", "w") as f:
    json.dump(wines, f)
print("results saved!")
# Out:
# all done! Saving results...
# results saved!

# %%
print(f"Before cleaning: {os.stat('../../../data.json').st_size // (1024 * 1024)} Mb")
print(f"After cleaning {os.stat('../../../data_cleaned.json').st_size // (1024 * 1024)} Mb")
# Out:
# Before cleaning: 1098 Mb
# After cleaning 572 Mb

# %%
print("Saving sample...")
with open("../../../data_sample_cleaned.json", "w") as f:
    json.dump(wines[:100], f)
print("Sample saved!")
# Out:
# Saving sample...
# Sample saved!
